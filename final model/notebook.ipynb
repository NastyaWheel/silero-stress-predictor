# %%
# !python /kaggle/input/stress/main.py
# Out:
# Starting fresh training with model StressLSTM
# Starting training at epoch 1 out of 8
#
# Epoch 1/8
# ...
# Validate: 100%|███████████████████████████████| 406/406 [00:05<00:00, 76.17it/s]
# Train Loss: 0.6173 | Train Acc: 74.60%
# Val Loss:   0.5559 | Val Acc:   77.62%
# Validation loss improved: inf --> 0.5559. Saving checkpoint.
# Saved new best model to best_model.pt
#
# Epoch 2/8
# ...
# Validate: 100%|███████████████████████████████| 406/406 [00:05<00:00, 77.35it/s]
# Train Loss: 0.4474 | Train Acc: 81.86%
# Val Loss:   0.5067 | Val Acc:   79.45%
# Validation loss improved: 0.5559 --> 0.5067. Saving checkpoint.
# Saved new best model to best_model.pt
#
# Epoch 3/8
# ...
# Validate: 100%|███████████████████████████████| 406/406 [00:05<00:00, 77.45it/s]
# Train Loss: 0.3547 | Train Acc: 86.09%
# Val Loss:   0.5048 | Val Acc:   80.81%
# Validation loss improved: 0.5067 --> 0.5048. Saving checkpoint.
# Saved new best model to best_model.pt
#
# Epoch 4/8
# ...
